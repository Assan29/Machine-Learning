# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from matplotlib import image
from PIL import ImageDraw, ImageFont
from PIL import Image

# %%
template3 = Image.open(r"C:\Users\kalag\Downloads\meme3.jpg")
font = ImageFont.truetype(r"C:\Users\kalag\Downloads\a_aha_wow\aAhaWow.ttf" , size = 42)
template3_Write = ImageDraw.Draw(template3)
template3_Write.text((50, 10), text = 'Innomatics Research Labs',font = font, fill = (229,9,20))
font = ImageFont.truetype(r"C:\Users\kalag\Downloads\a_aha_wow\aAhaWow.ttf" , size = 25)
template3_Write.text((15, 80), text = 'We just do not train,We transform the careers',font = font, fill = (0,0,0))
font = ImageFont.truetype(r"C:\Users\kalag\Downloads\a_aha_wow\aAhaWow.ttf" , size = 24)
template3_Write.text((30, 150), text = 'advanced training on IBM Certified Data Science,',font = font, fill = (0,0,139))
template3_Write.text((10, 190), text = 'Python,IBM Certified Predictive Analytics Modeler,',font = font, fill = (0,0,139))
template3_Write.text((30, 230), text = ' Machine Learning, Artificial Intelligence (AI)',font = font, fill = (0,0,139))
font = ImageFont.truetype(r"C:\Users\kalag\Downloads\a_aha_wow\aAhaWow.ttf" , size = 33)
template3_Write.text((45, 660), text = 'adi chalu ra...adi okkati unte chalu',font = font, fill = (0,0,0))
template3_Write.text((47, 655), text = 'adi chalu ra...adi okkati unte chalu',font = font, fill = (225,225,0))
plt.imshow(template3)

# %%
template3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=711x720>

# %%
template2 = Image.open(r"C:\Users\kalag\Downloads\meme2_clipdrop-remove-text_clipdrop-cleanup.jpg")
font = ImageFont.truetype(r"C:\Users\kalag\Downloads\a_aha_wow\aAhaWow.ttf" , size = 25)
template2_Write = ImageDraw.Draw(template2)
template2_Write.text((50, 250), text = 'abhilash sir*',font = font, fill = (255,255,0))
template2_Write.text((50, 430), text = 'ippudu neku ela',font = font, fill = (255,255,0))
template2_Write.text((60, 450), text = 'anipisthundhi',font = font, fill = (255,255,0))
template2_Write.text((350, 430), text = 'pranam poyinattu',font = font, fill = (0,0,139))
template2_Write.text((370, 450), text = 'anipisthundhi',font = font, fill = (0,0,139))
template2_Write.text((50, 660), text = 'meru time ki',font = font, fill = (0,0,139))
template2_Write.text((230, 660), text = 'assignment,task',font = font, fill = (255,255,0))
template2_Write.text((470, 660), text = 'complete',font = font, fill = (0,0,139))
template2_Write.text((70, 690), text = 'cheyapothe naku alaane vuntundhi...',font = font, fill = (0,0,139))
plt.imshow(template2)

# %%
template = Image.open(r"C:\Users\kalag\Downloads\memes.jpg")
template = Image.open(r"C:\Users\kalag\Downloads\memes.jpg")
template_Write = ImageDraw.Draw(template)
font = ImageFont.truetype(r"C:\Users\kalag\Downloads\a_aha_wow\aAhaWow.ttf" , size = 20)
template_Write.text((170, 40), text = '**Mam The Trainee',font = font, fill = (255,255,255))
template_Write.text((50, 250), text = 'asking miku ardham ithundha',font = font, fill = (255,255,255))
template_Write.text((340, 310), text = '**you don\'t known',font = font, fill = (255,255,0))
template_Write.text((420, 330), text = 'topic name',font = font, fill = (255,255,0))
template_Write.text((90, 510), text = 'mam meru nannu nijangane ee',font = font, fill = (255,255,0))
template_Write.text((120, 530), text = 'question aduguthunnara..',font = font, fill = (255,255,0))
plt.imshow(template)

# %%
template
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=554x554>

# %%
netflixcanva = Image.new(mode = 'RGB', size = (399, 186), color = (0,0,0))
netfWrite = ImageDraw.Draw(netflixcanva)
font = ImageFont.truetype(r"C:\Users\kalag\Downloads\Roboto-Bold.ttf", size = 60)
netfWrite.text((80, 60), text = 'NETFLIX',font = font, fill = (229, 9, 20))
plt.imshow(netflixcanva)

# %%
ahaCanva = Image.new(mode = 'RGB', size = (399, 186), color = (255,99,71))
ahaWrite = ImageDraw.Draw(ahaCanva)
font = ImageFont.truetype(r"C:\Users\kalag\Downloads\a_aha_wow\aAhaWow.ttf" , size = 90)
ahaWrite.text((110, 60), text = 'aha',font = font, fill = (255,255,255))
plt.imshow(ahaCanva)

# %%
plt.figure(figsize = (20,10))

plt.subplot(2,2,1)
plt.title('NETFLIX')
plt.imshow(netflixcanva)

plt.subplot(2,1,2)
plt.title('AHA')
plt.imshow(ahaCanva)
